# %% [markdown]
# # Decoder Locality Analysis
#
# ## Goal (H2: patch token-edit on decoder)
# We **edit token IDs inside a contiguous token-space patch** (`patch_bbox_tok`) and decode to pixels.
# The question is: **does the decoded image change mostly inside the corresponding pixel patch** (`patch_bbox_px`)?
#
# For each image:
# 1) Encode the image with the VQGAN encoder to a discrete token grid
#    $z \in \{0,\dots,K-1\}^{H_{\text{tok}}\times W_{\text{tok}}}$.
#
# 2) Choose a contiguous token patch $B_{\text{tok}}$ and create an edited grid $\tilde z$ by replacing token IDs **only inside** that patch, using `token_edit_mode`.
#
# 3) Decode both grids:
# - $x_{\text{clean}} = D(z)$
# - $x_{\text{edit}} = D(\tilde z)$
#
# 4) Measure locality in **pixel space**: does the change $|x_{\text{edit}} - x_{\text{clean}}|$ stay mostly inside the projected pixel box `patch_bbox_px`?
#
# ## record format
#
# Each JSONL row corresponds to one ImageNet validation image (identified by `image_id`) and one deterministic “token-patch edit” experiment run on its VQGAN reconstruction.
#
# - `token_edit_mode = "random_uniform"`
#   Inside the edited token patch, token IDs are replaced by **random IDs sampled uniformly** from the codebook.
#
# - `token_grid_hw = [H_tok, W_tok]`
#   Spatial resolution of the latent token grid. In our setup it is `[16, 16]` so the image is represented by a 16×16 grid of discrete codebook indices (256 total tokens).
#
# - `patch_bbox_tok = [j0, i0, j1, i1]`
#   The **token-space** axis-aligned rectangle that is edited.
#   Convention: `i` is row, `j` is column.
#   The set of edited token positions is
#   $$
#   \{(i,j)\;|\; i_0 \le i < i_1,\; j_0 \le j < j_1\}.
#   $$
#
# - `patch_bbox_px = [x0, y0, x1, y1]`
#   The **pixel-space** rectangle that corresponds to the edited token patch (projected into the decoded image coordinates). This is what we use to define “inside” and “outside” in pixel-space locality metrics.
#
# - `indices_clean` (length 256)
#   Flattened clean token grid (row-major flattening of the 16×16 grid).
#
# - `indices_edit` (length 256)
#   Flattened token grid after editing the patch (should differ from clean mostly inside `patch_bbox_tok`).
#
# - Images on disk (under `images/<class>/<id>/`):
#   - `0_original.png`: original ImageNet image (reference)
#   - `1_recon_clean.png`: VQGAN reconstruction from `indices_clean`
#   - `2_recon_token_edit.png`: VQGAN reconstruction from `indices_edit`
#   -

# %% [markdown]
# ## Sanity Check

# %%
from pathlib import Path

OUTDIR = Path("/exp/1766011502_robustness_dataset_vqgan_h2_patch_token_edit_decoder")  # <-- change if needed
IMAGES_DIR = OUTDIR / "images"

meta_files = sorted(OUTDIR.glob("metadata_part_*.jsonl"))
print("OUTDIR:", OUTDIR)
print("IMAGES_DIR exists:", IMAGES_DIR.exists())
print("Found metadata files:", len(meta_files))
for p in meta_files[:10]:
    print(" -", p.name)

assert OUTDIR.exists(), "OUTDIR does not exist"
assert len(meta_files) > 0, "No metadata_part_*.jsonl files found. Fix OUTDIR."
assert IMAGES_DIR.exists(), f"Missing folder: {IMAGES_DIR}"
# Out:
# OUTDIR: /exp/1766011502_robustness_dataset_vqgan_h2_patch_token_edit_decoder
# IMAGES_DIR exists: True
# Found metadata files: 8
#  - metadata_part_0.jsonl
#  - metadata_part_1.jsonl
#  - metadata_part_2.jsonl
#  - metadata_part_3.jsonl
#  - metadata_part_4.jsonl
#  - metadata_part_5.jsonl
#  - metadata_part_6.jsonl
#  - metadata_part_7.jsonl

# %%
import json

MAX_RECORDS = None  # e.g. 5000 for a quick pass, or None for all

def iter_records(meta_paths, max_records=None):
    n = 0
    for fp in meta_paths:
        with open(fp, "r") as f:
            for line in f:
                if not line.strip():
                    continue
                yield json.loads(line)
                n += 1
                if max_records is not None and n >= max_records:
                    return

records_small = []
for rec in iter_records(meta_files, MAX_RECORDS):
    # image_id is "n01440764/ILSVRC2012_val_00000293" (class_id/filename)
    image_id = rec.get("image_id", None)
    bb_px = rec.get("patch_bbox_px", None)
    bb_tok = rec.get("patch_bbox_tok", None)
    hw_tok = rec.get("token_grid_hw", None)
    records_small.append({
        "image_id": image_id,
        "patch_bbox_px": bb_px,
        "patch_bbox_tok": bb_tok,
        "token_grid_hw": hw_tok,
        # keep raw indices only if you want token-sanity later; otherwise skip
        "indices_clean": rec.get("indices_clean", None),
        "indices_edit": rec.get("indices_edit", None),
        "token_edit_mode": rec.get("token_edit_mode", None),
    })

print("Loaded records:", len(records_small))
print("Example keys:", list(records_small[0].keys()) if records_small else None)
print("Example image_id:", records_small[0]["image_id"] if records_small else None)
# Out:
# Loaded records: 50000
# Example keys: ['image_id', 'patch_bbox_px', 'patch_bbox_tok', 'token_grid_hw', 'indices_clean', 'indices_edit', 'token_edit_mode']
# Example image_id: n01440764/ILSVRC2012_val_00000293

# %%
# visual sanity with BOTH pixel bbox (solid) and token bbox projection (dashed)
import numpy as np
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import random

def load_img_float01(p: Path) -> np.ndarray:
    arr = np.array(Image.open(p).convert("RGB"), dtype=np.float32)
    return arr / 255.0

def tokbox_to_pxbox(bb_tok, H, W, Htok, Wtok):
    # bb_tok = (j0, i0, j1, i1)
    j0, i0, j1, i1 = map(int, bb_tok)
    sx = W / float(Wtok)
    sy = H / float(Htok)
    x0 = j0 * sx
    x1 = j1 * sx
    y0 = i0 * sy
    y1 = i1 * sy
    return x0, y0, x1, y1

def show_triplet_with_bboxes(image_id, bbox_px, bbox_tok, tok_hw, images_root: Path):
    ps = paths_for_sample(images_root, image_id)

    x_orig  = load_img_float01(ps["orig"]) if ps["orig"].exists() else None
    x_clean = load_img_float01(ps["recon_clean"])
    x_edit  = load_img_float01(ps["recon_edit"])

    titles_imgs = []
    if x_orig is not None:
        titles_imgs.append(("original", x_orig))
    titles_imgs += [("recon_clean", x_clean), ("recon_token_edit", x_edit)]

    fig, axes = plt.subplots(1, len(titles_imgs), figsize=(5 * len(titles_imgs), 4))
    if len(titles_imgs) == 1:
        axes = [axes]

    for ax, (title, img) in zip(axes, titles_imgs):
        ax.imshow(img)
        ax.set_title(title)
        ax.axis("off")

        # Only overlay on recon images (bbox definitions are for decoded space)
        if title == "original":
            continue

        H, W = img.shape[0], img.shape[1]

        # 1) exported pixel bbox (solid)
        if bbox_px is not None:
            x0, y0, x1, y1 = map(int, bbox_px)
            rect_px = patches.Rectangle(
                (x0, y0), x1 - x0, y1 - y0,
                linewidth=2, fill=False
            )
            ax.add_patch(rect_px)

        # 2) token bbox projected to pixels (dashed)
        if bbox_tok is not None and tok_hw is not None:
            Htok, Wtok = map(int, tok_hw)
            tx0, ty0, tx1, ty1 = tokbox_to_pxbox(bbox_tok, H, W, Htok, Wtok)
            rect_tok = patches.Rectangle(
                (tx0, ty0), tx1 - tx0, ty1 - ty0,
                linewidth=2, fill=False, linestyle="--"
            )
            ax.add_patch(rect_tok)

    plt.suptitle(image_id + "  (solid=patch_bbox_px, dashed=patch_bbox_tok→px)")
    plt.show()

random.seed(1)
for r in random.sample(records_small, k=min(3, len(records_small))):
    if r["image_id"]:
        show_triplet_with_bboxes(
            r["image_id"],
            r.get("patch_bbox_px"),
            r.get("patch_bbox_tok"),
            r.get("token_grid_hw"),
            IMAGES_DIR
        )

# %% [markdown]
# ### Token-space sanity
# *(Did we actually edit the intended patch?)*
#
# #### Definitions
#
# Let the token grid be
# $ z \in \{0,\dots,K-1\}^{H_{\text{tok}} \times W_{\text{tok}}} $.
#
# Here:
# - $H_{\text{tok}}, W_{\text{tok}}$ denote the latent token grid resolution
#   (for VQGAN, $16 \times 16$ in our setup).
#
# Let:
# - $\text{indices}_{\text{clean}}$ be the flattened clean token grid
# - $\text{indices}_{\text{edit}}$ be the flattened edited token grid
# - $B_{\text{tok}} = (j_0,i_0,j_1,i_1)$ be the token-space bounding box that is edited
#
# The token-space patch area is:
# $$
# A_{\text{tok}} = (j_1 - j_0)(i_1 - i_0).
# $$
#
# The empirical fraction of edited tokens is:
# $$
# \text{token\_edit\_fraction}
# =
# \frac{1}{H_{\text{tok}} W_{\text{tok}}}
# \sum_k
# \mathbf{1}\!\left[
# \text{indices}_{\text{edit}}(k)
# \neq
# \text{indices}_{\text{clean}}(k)
# \right].
# $$
#
# ### Why this sanity check exists
#
# The expected edit fraction is
# $$
# \frac{A_{\text{tok}}}{H_{\text{tok}} W_{\text{tok}}}.
# $$
#
# If the measured $\text{token\_edit\_fraction}$ deviates significantly from this value, then the subsequent decoder locality analysis is invalid. Such a mismatch indicates that either the wrong tokens were modified or that the image-to-token bounding box mapping is inconsistent.

# %%
# token-space sanity check (edit fraction vs expected patch area)
import numpy as np
import pandas as pd

def infer_tok_hw(rec):
    hw = rec.get("token_grid_hw", None)
    if hw is None:
        return None
    return int(hw[0]), int(hw[1])

def token_edit_fraction(indices_clean, indices_edit):
    a = np.asarray(indices_clean, dtype=np.int64)
    b = np.asarray(indices_edit, dtype=np.int64)
    return float(np.mean(a != b))

rows = []
for r in records_small:
    if r["indices_clean"] is None or r["indices_edit"] is None:
        continue
    hw = infer_tok_hw(r)
    bb_tok = r.get("patch_bbox_tok", None)
    if hw is None or bb_tok is None:
        continue
    Htok, Wtok = hw
    j0, i0, j1, i1 = map(int, bb_tok)  # note: (j0,i0,j1,i1)
    patch_area = max(0, j1-j0) * max(0, i1-i0)
    expected = patch_area / float(Htok * Wtok)

    frac = token_edit_fraction(r["indices_clean"], r["indices_edit"])
    rows.append({
        "image_id": r["image_id"],
        "Htok": Htok, "Wtok": Wtok,
        "patch_area_tok": patch_area,
        "expected_edit_fraction": expected,
        "token_edit_fraction": frac,
        "delta_fraction": frac - expected,
    })

df_tok = pd.DataFrame(rows)
print("Token sanity rows:", len(df_tok))
df_tok.describe(percentiles=[0.5, 0.9, 0.99])
# Out:
# Token sanity rows: 50000
#           Htok     Wtok  patch_area_tok  expected_edit_fraction  \
# count  50000.0  50000.0    50000.000000            50000.000000
# mean      16.0     16.0       79.753760                0.311538
# std        0.0      0.0        3.214824                0.012558
# min       16.0     16.0       64.000000                0.250000
# 50%       16.0     16.0       81.000000                0.316406
# 90%       16.0     16.0       81.000000                0.316406
# 99%       16.0     16.0       81.000000                0.316406
# max       16.0     16.0       81.000000                0.316406
#
#        token_edit_fraction  delta_fraction
# count         50000.000000    50000.000000
# mean              0.311518       -0.000020
# std               0.012558        0.000281
# min               0.250000       -0.007812
# 50%               0.316406        0.000000
# 90%               0.316406        0.000000
# 99%               0.316406        0.000000
# ...

# %%
# token sanity extremes (to spot obvious mismatches)
if len(df_tok):
    print("Largest |delta_fraction|:")
    display(df_tok.reindex(df_tok["delta_fraction"].abs().sort_values(ascending=False).index).head(10)[
        ["image_id","expected_edit_fraction","token_edit_fraction","delta_fraction","patch_area_tok","Htok","Wtok"]
    ])
# Out:
# Largest |delta_fraction|:
#                                 image_id  expected_edit_fraction  \
# 8914   n02799071/ILSVRC2012_val_00009184                0.316406
# 36793  n04548280/ILSVRC2012_val_00008740                0.316406
# 38844  n02100236/ILSVRC2012_val_00039487                0.316406
# 12903  n01744401/ILSVRC2012_val_00043969                0.316406
# 16964  n03930313/ILSVRC2012_val_00010851                0.316406
# 19063  n01728572/ILSVRC2012_val_00033762                0.316406
# 48589  n04131690/ILSVRC2012_val_00045582                0.316406
# 34608  n03255030/ILSVRC2012_val_00028417                0.281250
# 27621  n02795169/ILSVRC2012_val_00028797                0.316406
# 38137  n01871265/ILSVRC2012_val_00003650                0.281250
#
#        token_edit_fraction  delta_fraction  patch_area_tok  Htok  Wtok
# 8914              0.308594       -0.007812              81    16    16
# 36793             0.312500       -0.003906              81    16    16
# ...

# %% [markdown]
# Interpretation: the edit operation is behaving exactly as designed. We are editing almost exclusively the intended patch, with tiny discrete deviations explainable by bbox rounding / clipping near image borders.

# %% [markdown]
# ### Pixel-space locality metrics (core of H2)
#
# #### Definition of the change map
# Let:
# - $x_{\text{clean}}$ be `1_recon_clean.png`
# - $x_{\text{edit}}$ be `2_recon_token_edit.png`
#
# Define the per-pixel change magnitude (channel-averaged L1):
# $$
# \Delta(u,v) = \frac{1}{3}\sum_{c=1}^{3}\left|x_{\text{edit}}(u,v,c) - x_{\text{clean}}(u,v,c)\right|.
# $$
#
# ### Inside vs outside change
# Let `patch_bbox_px = (x_0,y_0,x_1,y_1)` and define:
# - inside region: $R = [x_0,x_1)\times[y_0,y_1)$
# - outside region: $R^c$ (all other pixels)
#
# We compute:
# $$
# \text{inside\_change} = \mathbb{E}[\Delta \mid (u,v)\in R],
# \quad
# \text{outside\_change} = \mathbb{E}[\Delta \mid (u,v)\in R^c].
# $$
#
# ### Leakage ratio
# $$
# \text{leakage\_ratio} =
# \frac{\text{outside\_change}}{\text{inside\_change}+\varepsilon}.
# $$
# A small leakage ratio indicates decoder locality: the edit mainly affects pixels inside the target region.
#
# ### Why we also track tails
# Even if the mean outside change is small, there can be rare global ripples.
# So we compute high percentiles of $\Delta$ outside the patch (`outside_p99`, `outside_p999`) to detect occasional but strong leakage.
#
# ### Δ heatmaps
#
# #### Definition
# For each pixel \((u,v)\), we compute the channel-averaged absolute difference between the two reconstructions:
# $$
# \Delta(u,v) = \frac{1}{3}\sum_{c=1}^{3}\left|x_{\text{edit}}(u,v,c) - x_{\text{clean}}(u,v,c)\right|.
# $$
# So $\Delta$ is a nonnegative “change magnitude map”: bright means “changed a lot”, dark means “unchanged”.
# heatmaps provide:
#
# 1) **Immediate locality sanity**
# If the decoder were perfectly local, the bright region would mostly sit inside the cyan box.
# If you see strong brightness outside the box, that’s leakage, full stop.
#
# 2) **Leakage *type* not just leakage *amount***
# The mean outside change can be small while still having a few bright streaks far away. A heatmap shows:
# - “edge-only blur” (changes bleed a few pixels past the boundary)
# - “global ripples” (low-amplitude changes everywhere)
# - “structure-coupled leakage” (changes follow object boundaries, textures, long contours)
#
# 3) **Detect mapping bugs**
# If the bright region is consistently shifted relative to the box, your `patch_bbox_px` mapping is wrong.
# If it aligns but still spills, that’s real decoder coupling.

# %%
# Δ heatmap sanity (where did pixels change?)
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import random

def delta_map(x_clean, x_edit) -> np.ndarray:
    # mean over channels L1
    return np.mean(np.abs(x_edit - x_clean), axis=-1)

def show_delta(image_id, bbox_px, images_root: Path):
    ps = paths_for_sample(images_root, image_id)
    x_clean = load_img_float01(ps["recon_clean"])
    x_edit  = load_img_float01(ps["recon_edit"])
    d = delta_map(x_clean, x_edit)

    plt.figure(figsize=(5,4))
    plt.imshow(d, cmap="magma")
    plt.axis("off")
    if bbox_px is not None:
        x0, y0, x1, y1 = map(int, bbox_px)
        rect = patches.Rectangle((x0, y0), x1-x0, y1-y0, linewidth=2, fill=False, edgecolor="cyan")
        plt.gca().add_patch(rect)
    plt.title(f"Δ heatmap: {image_id}")
    plt.show()

random.seed(2)
for r in random.sample(records_small, k=min(3, len(records_small))):
    if r["image_id"] and r["patch_bbox_px"]:
        show_delta(r["image_id"], r["patch_bbox_px"], IMAGES_DIR)

# %%
# core pixel locality metrics per sample
import numpy as np
import pandas as pd

EPS = 1e-8

def inside_outside_stats(d: np.ndarray, bbox_px):
    H, W = d.shape
    x0, y0, x1, y1 = map(int, bbox_px)
    x0 = max(0, min(W, x0)); x1 = max(0, min(W, x1))
    y0 = max(0, min(H, y0)); y1 = max(0, min(H, y1))

    inside = d[y0:y1, x0:x1]
    inside_sum = float(inside.sum())
    inside_cnt = int(inside.size)

    total_sum = float(d.sum())
    total_cnt = int(d.size)

    outside_sum = total_sum - inside_sum
    outside_cnt = total_cnt - inside_cnt

    inside_mean = inside_sum / (inside_cnt + EPS)
    outside_mean = outside_sum / (outside_cnt + EPS)
    leakage_ratio = outside_mean / (inside_mean + EPS)

    # outside tail without building a full boolean mask
    outside_vals = []
    if y0 > 0: outside_vals.append(d[:y0, :].ravel())
    if y1 < H: outside_vals.append(d[y1:, :].ravel())
    if x0 > 0: outside_vals.append(d[y0:y1, :x0].ravel())
    if x1 < W: outside_vals.append(d[y0:y1, x1:].ravel())
    outside_flat = np.concatenate(outside_vals) if outside_vals else np.array([], dtype=d.dtype)

    outside_p99 = float(np.percentile(outside_flat, 99)) if outside_flat.size else 0.0
    outside_p999 = float(np.percentile(outside_flat, 99.9)) if outside_flat.size else 0.0

    return inside_mean, outside_mean, leakage_ratio, outside_p99, outside_p999

MAX_IMAGES_FOR_PIXEL_METRICS = None  # e.g. 5000 for speed, or None for all

rows = []
n_done = 0
for r in records_small:
    if r["image_id"] is None or r["patch_bbox_px"] is None:
        continue
    ps = paths_for_sample(IMAGES_DIR, r["image_id"])
    if not (ps["recon_clean"].exists() and ps["recon_edit"].exists()):
        continue

    x_clean = load_img_float01(ps["recon_clean"])
    x_edit  = load_img_float01(ps["recon_edit"])
    d = delta_map(x_clean, x_edit)

    inside_mean, outside_mean, leak, out_p99, out_p999 = inside_outside_stats(d, r["patch_bbox_px"])
    rows.append({
        "image_id": r["image_id"],
        "inside_change": inside_mean,
        "outside_change": outside_mean,
        "leakage_ratio": leak,
        "outside_p99": out_p99,
        "outside_p999": out_p999,
    })

    n_done += 1
    if MAX_IMAGES_FOR_PIXEL_METRICS is not None and n_done >= MAX_IMAGES_FOR_PIXEL_METRICS:
        break

df_pix = pd.DataFrame(rows)
print("Pixel-metric rows:", len(df_pix))
df_pix.describe(percentiles=[0.5, 0.9, 0.99])
# Out:
# Pixel-metric rows: 50000
#        inside_change  outside_change  leakage_ratio   outside_p99  \
# count   50000.000000    50000.000000   50000.000000  50000.000000
# mean        0.210818        0.066270       0.330568      0.368457
# std         0.058536        0.019028       0.107624      0.087344
# min         0.025464        0.011032       0.063411      0.057516
# 50%         0.207641        0.064272       0.314609      0.367320
# 90%         0.287227        0.091468       0.471654      0.481686
# 99%         0.365187        0.118714       0.654983      0.576471
# max         0.543203        0.171672       1.054436      0.732667
#
#        outside_p999
# count  50000.000000
# mean       0.522445
# std        0.117360
# min        0.114835
# 50%        0.520064
# 90%        0.675422
# 99%        0.804834
# max        0.992157

# %% [markdown]
# #### Aggregate pixel-locality statistics (50k images)
#
# Table above summarizes the distribution of the pixel-space locality metrics over the full ImageNet validation set.
#
# - The token edit induces a substantial change inside the target region:
#   mean `inside_change` = 0.211
# - Changes outside the target region are smaller but clearly non-zero:
#   mean `outside_change` = 0.066
#
# Taken together, the average leakage ratio is:
# - mean `leakage_ratio` = 0.331 x
#
# meaning the decoder’s out-of-patch change magnitude is roughly one third of the in-patch magnitude on average. This indicates **partial locality**: the edit affects the intended region most strongly, but it also propagates beyond the patch.
#
# Importantly, leakage is heavy-tailed. While the mean outside change is moderate, the high-percentile statistics are large:
# - `outside_p99` ≈ 0.368 and `outside_p999` ≈ 0.522 (with maxima approaching 1.0),
#
# showing that a small fraction of pixels outside the patch can change dramatically. This motivates inspecting qualitative Δ heatmaps and distance-to-patch profiles to characterize whether leakage is primarily boundary-adjacent or genuinely long-range.

# %%
# best/worst leakage examples (quantitative)
if len(df_pix):
    print("Lowest leakage_ratio:")
    display(df_pix.sort_values("leakage_ratio").head(10))
    print("Highest leakage_ratio:")
    display(df_pix.sort_values("leakage_ratio", ascending=False).head(10))
# Out:
# Lowest leakage_ratio:
#                                 image_id  inside_change  outside_change  \
# 40706  n03075370/ILSVRC2012_val_00036697       0.297308        0.018853
# 571    n01828970/ILSVRC2012_val_00038288       0.340625        0.023460
# 6030   n07892512/ILSVRC2012_val_00020506       0.326039        0.023027
# 41787  n03825788/ILSVRC2012_val_00039100       0.415580        0.029866
# 42610  n04270147/ILSVRC2012_val_00016601       0.400097        0.028921
# 48022  n03838899/ILSVRC2012_val_00020624       0.301655        0.021875
# 46401  n02790996/ILSVRC2012_val_00028259       0.349828        0.026117
# 41740  n03793489/ILSVRC2012_val_00012780       0.328394        0.024550
# 21703  n02974003/ILSVRC2012_val_00000085       0.336172        0.025580
# 17709  n04355933/ILSVRC2012_val_00013274       0.391867        0.030230
#
#        leakage_ratio  outside_p99  outside_p999
# 40706       0.063411     0.274510      0.510914
# 571         0.068875     0.379085      0.578888
# ...

# %% [markdown]
# ### Best / worst examples (by leakage ratio)
#
# Table above lists the 10 samples with the smallest and largest
# $$
# \text{leakage\_ratio}=\frac{\text{outside\_change}}{\text{inside\_change}+\varepsilon}.
# $$
#
# **How to interpret these extremes:**
#
# - **Lowest leakage ratio** cases correspond to strong, spatially confined effects: the token edit produces a large change inside the target region while the rest of the image remains comparatively stable (high `inside_change`, low `outside_change`). These are the clearest examples of decoder locality.
#
# - **Highest leakage ratio** cases do **not necessarily** mean “outside exploded”. In many of these samples the ratio is large because the edit has a **weak effect inside** (small `inside_change`), making `outside_change` comparable in scale. In other words, “worst by ratio” is often **low signal inside**, not pure global leakage.
#
# For this reason, we complement ratio-based selection with tail-sensitive statistics (`outside_p99`, `outside_p999`) and qualitative Δ heatmaps. The percentiles capture rare but strong out-of-patch changes that may not move the mean `outside_change` much, while the heatmaps reveal whether leakage is diffuse (global coupling) or structured along edges/textures (continuity effects).

# %%
def show_triplet(image_id, bbox_px, images_root: Path):
    ps = paths_for_sample(images_root, image_id)

    x_orig  = load_img_float01(ps["orig"]) if ps["orig"].exists() else None
    x_clean = load_img_float01(ps["recon_clean"])
    x_edit  = load_img_float01(ps["recon_edit"])
    d = delta_map(x_clean, x_edit)

    # build columns dynamically
    cols = []
    if x_orig is not None:
        cols.append(("orig", x_orig))
    cols += [("recon_clean", x_clean), ("recon_token_edit", x_edit)]

    ncols = len(cols) + 1  # +1 for heatmap
    fig, axes = plt.subplots(1, ncols, figsize=(4.5 * ncols, 4))

    if ncols == 1:
        axes = [axes]

    for i, (title, img) in enumerate(cols):
        ax = axes[i]
        ax.imshow(img)
        ax.axis("off")
        ax.set_title(title)
        if bbox_px is not None:
            x0, y0, x1, y1 = map(int, bbox_px)
            rect = patches.Rectangle(
                (x0, y0), x1 - x0, y1 - y0,
                linewidth=2, fill=False
            )
            ax.add_patch(rect)

    # Δ heatmap (last column)
    ax = axes[-1]
    ax.imshow(d, cmap="magma")
    ax.axis("off")
    ax.set_title("Δ heatmap")
    if bbox_px is not None:
        x0, y0, x1, y1 = map(int, bbox_px)
        rect = patches.Rectangle(
            (x0, y0), x1 - x0, y1 - y0,
            linewidth=2, fill=False, edgecolor="cyan"
        )
        ax.add_patch(rect)

    plt.suptitle(image_id)
    plt.tight_layout()
    plt.show()

# %%
# join bbox back in
bbox_map = {r["image_id"]: r["patch_bbox_px"] for r in records_small if r["image_id"] and r["patch_bbox_px"]}

if len(df_pix):
    best_ids = df_pix.sort_values("leakage_ratio").head(3)["image_id"].tolist()
    worst_ids = df_pix.sort_values("leakage_ratio", ascending=False).head(3)["image_id"].tolist()

    print("Best (lowest leakage):")
    for iid in best_ids:
        show_triplet(iid, bbox_map.get(iid), IMAGES_DIR)

    print("Worst (highest leakage):")
    for iid in worst_ids:
        show_triplet(iid, bbox_map.get(iid), IMAGES_DIR)
# Out:
# Best (lowest leakage):
# Worst (highest leakage):

# %%
# qualitative extremes (absolute leakage, not ratio artifacts)

K = 10

print("Highest outside_change:")
display(df_pix.sort_values("outside_change", ascending=False).head(K))

# join df_pix and df_band by image_id for far-field ranking
df_join = df_pix.merge(df_band[["image_id","far_mean","far_p99","ring_mean"]], on="image_id", how="left")

print("Highest far_mean (global coupling):")
display(df_join.sort_values("far_mean", ascending=False).head(K))

print("Highest outside_p99 (rare strong outside spikes):")
display(df_pix.sort_values("outside_p99", ascending=False).head(K))
# Out:
# Highest outside_change:
#                                 image_id  inside_change  outside_change  \
# 28700  n03530642/ILSVRC2012_val_00027423       0.205587        0.171672
# 21776  n03000247/ILSVRC2012_val_00027729       0.225968        0.171463
# 43881  n01582220/ILSVRC2012_val_00030017       0.209796        0.171336
# 35725  n03938244/ILSVRC2012_val_00043608       0.239556        0.168959
# 18216  n06596364/ILSVRC2012_val_00014976       0.268459        0.163143
# 31853  n01872401/ILSVRC2012_val_00003827       0.218728        0.163095
# 38369  n02013706/ILSVRC2012_val_00015167       0.220244        0.160802
# 12562  n01530575/ILSVRC2012_val_00034864       0.210253        0.158763
# 15657  n03065424/ILSVRC2012_val_00001981       0.322330        0.157534
# 30316  n04435653/ILSVRC2012_val_00044956       0.239197        0.156773
#
#        leakage_ratio  outside_p99  outside_p999
# 28700       0.835032     0.651621      0.829671
# 21776       0.758790     0.614379      0.771242
# ...

# %%
# distance-to-patch leakage curve (Manhattan distance in pixels)
import numpy as np
import matplotlib.pyplot as plt

def dist_to_rect_manhattan(H, W, bbox_px):
    x0, y0, x1, y1 = map(int, bbox_px)
    xs = np.arange(W)[None, :]
    ys = np.arange(H)[:, None]

    # distance to interval [x0, x1-1]
    dx = np.where(xs < x0, x0 - xs, np.where(xs >= x1, xs - (x1 - 1), 0))
    dy = np.where(ys < y0, y0 - ys, np.where(ys >= y1, ys - (y1 - 1), 0))
    return (dx + dy).astype(np.int32)

def leakage_curve_for_sample(d, bbox_px, dist_max=128):
    H, W = d.shape
    dist = dist_to_rect_manhattan(H, W, bbox_px)
    dist_clip = np.minimum(dist, dist_max)

    # mean Δ at each distance bucket 0..dist_max
    sums = np.bincount(dist_clip.ravel(), weights=d.ravel(), minlength=dist_max+1)
    cnts = np.bincount(dist_clip.ravel(), minlength=dist_max+1)
    curve = sums / (cnts + 1e-8)
    return curve

DIST_MAX = 128
MAX_SAMPLES_FOR_CURVE = 5000  # keep this moderate; curves are heavier than scalar metrics

curves = []
n = 0
for r in records_small:
    iid = r["image_id"]
    bb = r["patch_bbox_px"]
    if iid is None or bb is None:
        continue
    ps = paths_for_sample(IMAGES_DIR, iid)
    if not (ps["recon_clean"].exists() and ps["recon_edit"].exists()):
        continue

    x_clean = load_img_float01(ps["recon_clean"])
    x_edit  = load_img_float01(ps["recon_edit"])
    d = delta_map(x_clean, x_edit)

    curves.append(leakage_curve_for_sample(d, bb, dist_max=DIST_MAX))
    n += 1
    if n >= MAX_SAMPLES_FOR_CURVE:
        break

curves = np.stack(curves, axis=0) if len(curves) else None
print("Curves computed:", 0 if curves is None else curves.shape[0])
# Out:
# Curves computed: 5000

# %%
# plot mean Δ vs distance (with a couple quantiles)
import numpy as np
import matplotlib.pyplot as plt

if curves is not None:
    mean_curve = curves.mean(axis=0)
    q50 = np.quantile(curves, 0.50, axis=0)
    q90 = np.quantile(curves, 0.90, axis=0)

    xs = np.arange(mean_curve.shape[0])

    plt.figure(figsize=(7,4))
    plt.plot(xs, mean_curve, label="mean")
    plt.plot(xs, q50, label="median")
    plt.plot(xs, q90, label="q90")
    plt.xlabel("Manhattan distance to patch (pixels, clipped)")
    plt.ylabel("E[Δ]")
    plt.title("Decoder leakage profile vs distance")
    plt.legend()
    plt.show()

# %% [markdown]
# #### Spatial leakage profile vs distance (diagnostic curve)
#
# To distinguish “boundary blur” from genuinely long-range coupling, we compute a distance-to-patch leakage curve.
# For each image we form the pixel change map $\Delta(u,v)$ and the Manhattan distance from each pixel to the edited rectangle:
# $$
# d(u,v) = \text{dist}_1\big((u,v), R\big),
# $$
# where $R$ is the pixel patch `patch_bbox_px` and $d(u,v)=0$ inside the patch.
#
# We then plot:
# $$
# \mathbb{E}[\Delta \mid d(u,v)=d]
# $$
# aggregated across images (mean, median, and 90th percentile).
#
# **Interpretation.** The curve drops rapidly with distance for the first $\sim$20–40 pixels, indicating that most change is concentrated near the edited region. However, it does not decay to zero: beyond roughly 50 pixels the mean/median curves plateau at a small but non-zero value. This plateau implies **global coupling in the decoder**: even far from the edited patch, pixels exhibit a persistent low-amplitude change.
#
# The elevated q90 curve indicates substantial heterogeneity across images: in at least 10% of samples, out-of-patch changes remain noticeably larger even at large distances, consistent with structured “leakage paths” observed in the qualitative Δ heatmaps (e.g., along edges or coherent object regions).

# %% [markdown]
# ## Boundary vs far-field decomposition
# The distance-to-patch curve suggests a rapid decay near the patch but a non-zero plateau. To quantify this cleanly, we split the outside region into two bands:
#
# - **Boundary ring:** pixels at Manhattan distance
#   $$
#   1 \le d(u,v) \le d_{\text{ring}}
#   $$
#   capturing immediate spillover around the patch boundary (typical “blur/continuity” effects).
#
# - **Far field:** pixels at distance
#   $$
#   d(u,v) \ge d_{\text{far}}
#   $$
#   capturing long-range coupling well away from the edited region.
#
# For each sample we compute the mean change magnitude in each band:
# $$
# \Delta_{\text{ring}} = \mathbb{E}[\Delta \mid 1 \le d \le d_{\text{ring}}],
# \qquad
# \Delta_{\text{far}} = \mathbb{E}[\Delta \mid d \ge d_{\text{far}}].
# $$
#
# If leakage were purely a boundary phenomenon, we would expect $\Delta_{\text{ring}}$ to be elevated while $\Delta_{\text{far}}$ approaches zero. A non-trivial $\Delta_{\text{far}}$ indicates persistent global effects in the decoder.

# %%
# compute boundary-ring vs far-field stats (uses the same Δ and Manhattan distance)
import numpy as np
import pandas as pd

# choose these once and keep consistent with your distance curve scale
D_RING = 16   # ~1 token width if image is 256 and tok grid is 16 (token ~16 px)
D_FAR  = 64   # clearly far from patch

EPS = 1e-8

def dist_to_rect_manhattan(H, W, bbox_px):
    x0, y0, x1, y1 = map(int, bbox_px)
    xs = np.arange(W)[None, :]
    ys = np.arange(H)[:, None]
    dx = np.where(xs < x0, x0 - xs, np.where(xs >= x1, xs - (x1 - 1), 0))
    dy = np.where(ys < y0, y0 - ys, np.where(ys >= y1, ys - (y1 - 1), 0))
    return (dx + dy).astype(np.int32)

def ring_far_means(dmap: np.ndarray, bbox_px, d_ring=16, d_far=64):
    H, W = dmap.shape
    dist = dist_to_rect_manhattan(H, W, bbox_px)

    ring_mask = (dist >= 1) & (dist <= d_ring)
    far_mask  = (dist >= d_far)

    ring_mean = float(dmap[ring_mask].mean()) if ring_mask.any() else 0.0
    far_mean  = float(dmap[far_mask].mean())  if far_mask.any() else 0.0

    # optional tails in far field (cheap and informative)
    far_p99 = float(np.percentile(dmap[far_mask], 99)) if far_mask.any() else 0.0
    return ring_mean, far_mean, far_p99

rows_band = []
for r in records_small:
    iid = r.get("image_id")
    bb  = r.get("patch_bbox_px")
    if iid is None or bb is None:
        continue

    ps = paths_for_sample(IMAGES_DIR, iid)
    if not (ps["recon_clean"].exists() and ps["recon_edit"].exists()):
        continue

    x_clean = load_img_float01(ps["recon_clean"])
    x_edit  = load_img_float01(ps["recon_edit"])
    dmap = delta_map(x_clean, x_edit)

    ring_mean, far_mean, far_p99 = ring_far_means(dmap, bb, d_ring=D_RING, d_far=D_FAR)
    rows_band.append({
        "image_id": iid,
        "ring_mean": ring_mean,
        "far_mean": far_mean,
        "far_p99": far_p99,
    })

df_band = pd.DataFrame(rows_band)
print("Band rows:", len(df_band))
df_band.describe(percentiles=[0.5, 0.9, 0.99])
# Out:
# Band rows: 50000
#           ring_mean      far_mean       far_p99
# count  50000.000000  50000.000000  50000.000000
# mean       0.150953      0.037397      0.216494
# std        0.040609      0.018414      0.109144
# min        0.023594      0.000951      0.005229
# 50%        0.149428      0.033647      0.202614
# 90%        0.203231      0.062742      0.367344
# 99%        0.255327      0.093696      0.505882
# max        0.387210      0.162682      0.694118

# %% [markdown]
# ### Boundary vs far-field leakage (summary)
#
# The band decomposition separates *immediate spillover near the patch boundary* from *truly long-range effects*.
#
# - `ring_mean` (distance 1–16 px): mean 0.151 (median 0.149)
#   This is large. It confirms a strong “boundary ring” where the decoder propagates changes right outside the edited region, consistent with continuity/edge effects.
#
# - `far_mean` (distance ≥ 64 px): mean 0.037 (median 0.034)
#   This is not negligible. Even far from the patch, the reconstruction changes by a persistent low-amplitude amount, matching the non-zero plateau in the distance-to-patch curve.
#
# - `far_p99`: mean 0.216 (median 0.203; 99% up to 0.506; max 0.694)
#   This shows heavy tails in the far field: while the *average* far-field change is small, a small fraction of far-field pixels can still change substantially (rare global ripples / structure-coupled leakage).
#
# Overall: most leakage mass lives in the boundary ring, but there is a real, measurable far-field component, and it is heavy-tailed.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(df_band["ring_mean"].values, bins=80, alpha=0.7, label="ring_mean (1–16 px)")
plt.hist(df_band["far_mean"].values,  bins=80, alpha=0.7, label="far_mean (>=64 px)")
plt.xlabel("Mean Δ in band")
plt.ylabel("Count")
plt.title("Boundary ring vs far-field leakage (distribution)")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.scatter(df_band["ring_mean"].values, df_band["far_mean"].values, s=2, alpha=0.25)
plt.xlabel("ring_mean (1–16 px)")
plt.ylabel("far_mean (>=64 px)")
plt.title("Ring vs far-field leakage per image")
plt.show()

# %% [markdown]
# #### Visualising boundary vs far-field leakage
#
# the histogram compares the distribution of mean change magnitude in the **boundary ring** (1–16 px from the patch) versus the **far field** (≥64 px). The two distributions are well separated: `ring_mean` is typically around 0.15, while `far_mean` concentrates around 0.03–0.05. This confirms that most leakage energy is concentrated near the patch boundary (consistent with local continuity/edge effects), whereas far-field changes are substantially smaller in amplitude.
#
# the scatter plots `far_mean` against `ring_mean` per image. The relationship is positive but highly dispersed: for a given boundary leakage level, far-field leakage varies widely across samples. This suggests that long-range effects are not merely a deterministic function of “how strong the local change was”, but depend on image content and decoder dynamics (e.g., global tone/texture coupling or structured propagation along coherent objects). In particular, the presence of a noticeable upper tail in `far_mean` indicates that a subset of images exhibits non-trivial global coupling even when boundary leakage is moderate.

# %%
corr = df_band["ring_mean"].corr(df_band["far_mean"])
p_tail = (df_band["far_mean"] > df_band["far_mean"].quantile(0.99)).mean()
print("corr(ring_mean, far_mean) =", corr)
print("fraction in top 1% far_mean =", p_tail)

for thr in [0.06, 0.08, 0.10]:
    print(thr, float((df_band["far_mean"] > thr).mean()))
# Out:
# corr(ring_mean, far_mean) = 0.2504668313326634
# fraction in top 1% far_mean = 0.01
# 0.06 0.1187
# 0.08 0.0306
# 0.1 0.00608

# %% [markdown]
# ## Summary: Decoder locality results (H2)
#
# In H2 we test **decoder locality** by editing a contiguous patch of latent token IDs (`patch_bbox_tok`) and decoding both the clean and edited token grids to pixel space. Locality would mean that the decoded image changes primarily inside the corresponding pixel-space region (`patch_bbox_px`), with minimal change elsewhere.
#
# ### Sanity checks (token + geometry)
# - The token grid resolution is constant at \(H_{\text{tok}} \times W_{\text{tok}} = 16 \times 16\).
# - The empirical edited-token fraction matches the expected patch area fraction extremely closely (mean difference \(\approx -2\times 10^{-5}\)), indicating that the intended token patch was edited correctly and bbox mapping is consistent.
# - Visual overlays confirm that the projected token bbox (dashed) aligns closely with the exported pixel bbox (solid).
#
# ### Pixel-space locality (core quantitative result)
# Let $$\Delta(u,v)=\frac{1}{3}\sum_c |x_{\text{edit}}(u,v,c)-x_{\text{clean}}(u,v,c)|$$. We summarize locality by averaging \(\Delta\) inside vs outside the patch:
# - Mean `inside_change` = **0.211** (median 0.208)
# - Mean `outside_change` = **0.066** (median 0.064)
# - Mean `leakage_ratio` = **0.331** (median 0.315)
#
# Thus, on average the out-of-patch change magnitude is roughly **one third** of the in-patch change magnitude: the decoder is **partially local** (edits concentrate in the correct region), but leakage is clearly non-zero.
#
# Leakage is also **heavy-tailed**: although the average outside change is moderate, rare out-of-patch changes can be large (`outside_p99` ≈ 0.368, `outside_p999` ≈ 0.522; maxima near 1.0). This matches the qualitative Δ heatmaps, where leakage often appears as structured changes along edges/textures rather than uniform noise.
#
# ### Spatial leakage vs distance
# The distance-to-patch profile \(\mathbb{E}[\Delta \mid d]\) decays rapidly for the first \(\sim\)20–40 pixels, but does not go to zero; it plateaus at a small non-zero level, indicating a persistent far-field component (global coupling).
#
# ### Boundary vs far-field decomposition
# To separate immediate boundary spillover from long-range effects, we compute mean change in:
# - a **boundary ring** (1–16 px): mean `ring_mean` = **0.151**
# - a **far field** (≥64 px): mean `far_mean` = **0.037** (median 0.034)
#
# Most leakage energy lies near the boundary, but far-field change remains measurable and is heavy-tailed (`far_p99` median ≈ 0.203; 99% up to ≈ 0.506; max ≈ 0.694). The association between boundary leakage and far-field leakage is weak-to-moderate (Pearson \(r \approx 0.25\)), suggesting that long-range effects are not simply a scaled version of boundary bleed and depend on image content / decoder dynamics.
#
# ### Qualitative failure modes (extremes)
# Selecting “worst cases” by different criteria reveals distinct behaviours:
# - **High `outside_change` / high `far_mean`**: diffuse, global leakage where edits perturb the reconstruction well beyond the patch.
# - **High `outside_p99`**: sparse but severe out-of-patch spikes, typically aligned with edges, thin structures, or coherent objects that cross the patch boundary.
#
# ### Takeaway
# The VQGAN decoder exhibits **strong local response** to token edits (changes concentrate inside the target region), but is **not strictly local**: it produces both boundary-adjacent spillover and a persistent, sometimes heavy-tailed far-field component. This supports the conclusion that decoding introduces non-trivial long-range coupling even when token edits are spatially confined.
